# %%
import pandas as pd
import csv

# %%
posts_dictionary = {
    "1":{
    "year": "2011",
    "month": "07",
    "day": "13",
    "title": "here-i-am"
    },
    "2":{
    "year": "2011",
    "month": "07",
    "day": "18",
    "title": "the-naming-of-things"
    },
    "3":{
    "year": "2011",
    "month": "10",
    "day": "30",
    "title": "a-few-words"
    },
    "4":{
       "year": "2011",
    "month": "11",
    "day": "05",
    "title": "mirror-mirror" 
    },
    "5":{
       "year": "2011",
    "month": "11",
    "day": "23",
    "title": "home-safe" 
    },
    "6":{
       "year": "2011",
    "month": "12",
    "day": "04",
    "title": "give-thanks" 
    },
    "7":{
       "year": "2011",
    "month": "12",
    "day": "15",
    "title": "family" 
    },
    "8":{
       "year": "2012",
    "month": "01",
    "day": "04",
    "title": "whats-cooking" 
    },
    "9":{
       "year": "2012",
    "month": "02",
    "day": "19",
    "title": "hello-old-friend" 
    },
    "10":{
       "year": "2012",
    "month": "02",
    "day": "23",
    "title": "i-wished-i-could-fly" 
    },
    "11":{
       "year": "2012",
    "month": "03",
    "day": "04",
    "title": "stay" 
    },
    "12":{
       "year": "2012",
    "month": "03",
    "day": "15",
    "title": "shaken" 
    },
    "13":{
       "year": "2012",
    "month": "05",
    "day": "04",
    "title": "april" 
    },
    "14":{
       "year": "2012",
    "month": "05",
    "day": "13",
    "title": "for-george" 
    },
    "15":{
       "year": "2012",
    "month": "09",
    "day": "01",
    "title": "favourite-photographs" 
    },
    "16":{
       "year": "2012",
    "month": "11",
    "day": "16",
    "title": "little-boxes" 
    },
    "17":{
       "year": "2012",
    "month": "12",
    "day": "12",
    "title": "food-love-etc" 
    },
    "18":{
       "year": "2013",
    "month": "01",
    "day": "24",
    "title": "family-recipes" 
    },
    "19":{
       "year": "2013",
    "month": "04",
    "day": "07",
    "title": "something-about-faith" 
    },
    "20":{
       "year": "2013",
    "month": "06",
    "day": "13",
    "title": "where-it-goes" 
    },
    "21":{
       "year": "2013",
    "month": "09",
    "day": "26",
    "title": "more-than-words" 
    },
    "22":{
       "year": "2014",
    "month": "03",
    "day": "05",
    "title": "in-progress" 
    },
    "23":{
       "year": "2014",
    "month": "05",
    "day": "04",
    "title": "what-im-reading" 
    },
    "24":{
       "year": "2014",
    "month": "10",
    "day": "20",
    "title": "the-land-of-stones" 
    },
    "25":{
       "year": "2014",
    "month": "10",
    "day": "28",
    "title": "spark" 
    },
    "26":{
       "year": "2014",
    "month": "11",
    "day": "06",
    "title": "burn" 
    },
    "27":{
       "year": "2014",
    "month": "11",
    "day": "11",
    "title": "washing-dishes" 
    },
    "28":{
       "year": "2015",
    "month": "04",
    "day": "27",
    "title": "tiny-cracks" 
    },
    "29":{
       "year": "2015",
    "month": "07",
    "day": "21",
    "title": "marys-island" 
    },
    "30":{
       "year": "2015",
    "month": "09",
    "day": "21",
    "title": "here" 
    },
    "31":{
       "year": "2016",
    "month": "07",
    "day": "12",
    "title": "knowing" 
    },
    "32":{
       "year": "2016",
    "month": "07",
    "day": "25",
    "title": "run" 
    },
    "33":{
       "year": "2016",
    "month": "10",
    "day": "19",
    "title": "gifts" 
    },
    "34":{
       "year": "2017",
    "month": "05",
    "day": "29",
    "title": "bloom" 
    },
}

# %%
links = pd.read_csv("links.csv", header=None)
content = pd.read_csv("post_content.csv")
post_meta = pd.read_csv("posts.csv", header=None)
titles = pd.read_csv("titles.csv", header=None)

# %%
posts = titles.T

# %%
posts = posts.rename(index=str, columns={0: "title"})

# %%
posts["subtitle"] = "example"
posts["author"] = 1

# %%
posts.to_csv("post_content_to_upload.csv", index=False)

# %%
posts
# Out:
#                      title subtitle  author
# 0               Here I am…  example       1
# 1     The naming of things  example       1
# 2              A few words  example       1
# 3           Mirror, Mirror  example       1
# 4              Home. Safe.  example       1
# 5             Give thanks.  example       1
# 6                  Family.  example       1
# 7          What’s cooking.  example       1
# 8        Hello old friend.  example       1
# 9    I wished I could fly.  example       1
# 10                   Stay.  example       1
# 11                 Shaken.  example       1
# 12                  April.  example       1
# 13             For George.  example       1
# 14  Favourite photographs.  example       1
# 15           Little Boxes.  example       1
# 16        Food, love, etc.  example       1
# 17         Family recipes.  example       1
# 18  Something about faith.  example       1
# 19          Where it goes.  example       1
# 20        More than words.  example       1
# 21            In progress.  example       1
# 22       What I’m reading.  example       1
# 23     The land of stones.  example       1
# 24                  Spark.  example       1
# 25                   Burn.  example       1
# 26         Washing dishes.  example       1
# 27             Tiny cracks  example       1
# 28           Mary’s Island  example       1
# 29                   Here.  example       1
# 30                Knowing.  example       1
# 31                    Run.  example       1
# 32                   Gifts  example       1
# 33                   Bloom  example       1

# %%
post_meta
# Out:
#                                                   0   \
# 0  [<p><a class="entry-format-link" href="https:/...
#
#                                                   1   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   2   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   3   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   4   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   5   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   6   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   7   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   8   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   9   \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                          ...                          \
# 0                        ...
#
#                                                   24  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   25  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   26  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   27  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   28  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   29  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   30  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   31  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   32  \
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
#                                                   33
# 0  [<p>\n\t\t\tPosted <span class="by-author"> by...
#
# [1 rows x 34 columns]
